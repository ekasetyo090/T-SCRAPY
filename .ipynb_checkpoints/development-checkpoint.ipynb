# %%
import requests as req
import pandas as pd
import time
from urllib.parse import urlparse, unquote
import sqlite3
import os
from datetime import datetime
import pytz
from sqlalchemy import create_engine, inspect
import json

# %%
pd.set_option('display.max_columns', None)

# %%
def get_tokopedia_shop_product(shopId:str)->pd.DataFrame:
    pages_count=1
    data_list = []
    url = 'https://gql.tokopedia.com/graphql/ShopProducts'
    header = {'Content-Type': 'application/json',
              'Accept': '*/*',
              'Accept-Encoding': 'gzip, deflate, br',
              'Accept-Language': 'en-US,en;q=0.9,id;q=0.8',
              'Content-Length': '3974',
              'Dnt': '1',
              'Origin': 'https://www.tokopedia.com',
              'Referer': f'https://www.tokopedia.com/lovebonitoid/product/page/{pages_count}',
              'Sec-Ch-Ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
              'Sec-Ch-Ua-Mobile': '?0',
              'Sec-Ch-Ua-Platform': '"Windows"',
              'Sec-Fetch-Dest': 'empty',
              'Sec-Fetch-Mode': 'cors',
              'Sec-Fetch-Site': 'same-site',
              'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
              'X-Device': 'desktop-0.0',
              'X-Source': 'tokopedia-lite',
              'X-Tkpd-Lite-Service': 'zeus',
              'X-Version': 'a71fcbd'
             }
    payload = {"operationName": "ShopProducts",
               "query": "query ShopProducts($sid: String!, $source: String, $page: Int, $perPage: Int, $keyword: String, $etalaseId: String, $sort: Int, $user_districtId: String, $user_cityId: String, $user_lat: String, $user_long: String) { GetShopProduct(shopID: $sid, source: $source, filter: {page: $page, perPage: $perPage, fkeyword: $keyword, fmenu: $etalaseId, sort: $sort, user_districtId: $user_districtId, user_cityId: $user_cityId, user_lat: $user_lat, user_long: $user_long}) { status errors links { prev next __typename } data { name product_url product_id price { text_idr __typename } primary_image { original thumbnail resize300 __typename } flags { isSold isPreorder isWholesale isWishlist __typename } campaign { discounted_percentage original_price_fmt start_date end_date __typename } label { color_hex content __typename } label_groups { position title type url __typename } badge { title image_url __typename } stats { reviewCount rating averageRating __typename } category { id __typename } __typename } __typename } }",
               "variables": {"source": "shop",
                             "sid": shopId,
                             "page": pages_count,
                             "perPage": 80,
                             "etalaseId": "etalase",
                             "sort": 1,
                             "user_cityId": "",
                             "user_districtId": "",
                             "user_lat": "",
                             "user_long": ""
                            }
              }
    
    while True: 
        payload['variables']['page'] = pages_count
        retries = 0
        while retries < 11:
            try:
                request = req.post(url,headers=header,json=payload).json()
                if request is not None:
                    break
                else:
                    continue
            except (req.exceptions.ConnectionError) as e:
                print(f' error {e}')
                retries += 1
                time.sleep(3)
                print(f'try to sleep 3 second, tries count {retries}')
        #request = req.post(url,headers=header,json=payload).json()
        data = request['data']['GetShopProduct'].get('data')
        if len(data) <1:
            break
        else:
            for index in range(0,len(data),1):
                data_dict = {}
                data_dict['shopId'] = shopId
                data_dict['productListingStatus'] = 'True'
                data_dict['productName'] = data[index].get('name')
                data_dict['productUrl'] = data[index].get('product_url')
                data_dict['productId'] = data[index].get('product_id')
                if data[index].get('price') is not None:
                    data_dict['priceText'] = data[index]['price'].get('text_idr')
                else:
                    data_dict['priceText'] = None
                if data[index].get('campaign') is not None:
                    data_dict['discounted_percentage'] = data[index]['campaign'].get('discounted_percentage')
                    data_dict['original_price'] = data[index]['campaign'].get('original_price_fmt')
                    data_dict['start_date'] = data[index]['campaign'].get('start_date')
                    data_dict['end_date'] = data[index]['campaign'].get('end_date')
                else:
                    data_dict['discounted_percentage'] = None
                    data_dict['original_price'] = None
                    data_dict['start_date'] = None
                    data_dict['end_date'] = None    
                if data[index].get('primary_image') is not None:
                    data_dict['imageOriginal'] = data[index]['primary_image'].get('original')
                    data_dict['imageThumbnail'] = data[index]['primary_image'].get('thumbnail')
                    data_dict['imageResize300'] = data[index]['primary_image'].get('resize300')
                else:
                    data_dict['imageOriginal'] = None
                    data_dict['imageThumbnail'] = None
                    data_dict['imageResize300'] = None
                if data[index].get('flags') is not None:
                    data_dict['isSold'] = data[index]['flags'].get('isSold')
                    data_dict['isPreorder'] = data[index]['flags'].get('isPreorder')
                    data_dict['isWholesale'] = data[index]['flags'].get('isWholesale')
                else:
                    data_dict['isSold'] = None
                    data_dict['isPreorder'] = None
                    data_dict['isWholesale'] = None

                if data[index].get('badge') is not None:
                    data_dict['storeBadge'] = data[index]['badge'][0].get('title')
                else:
                    data_dict['storeBadge'] = None

                if data[index].get('stats') is not None:
                    data_dict['reviewCount'] = data[index]['stats'].get('reviewCount')
                    data_dict['rating'] = data[index]['stats'].get('rating')
                    data_dict['averageRating'] = data[index]['stats'].get('averageRating')
                else:
                    data_dict['reviewCount'] = None
                    data_dict['rating'] = None
                    data_dict['averageRating'] = None
                if data[index].get('category') is not None:
                    data_dict['Category'] = data[index]['category'].get('id')
                else:
                    data_dict['category'] = None
                if data_dict['productUrl'] is not None:
                    data_dict['shopDomain'] = (urlparse(data_dict['productUrl']).path).split('/')[1]
                    data_dict['productKey'] = (urlparse(data_dict['productUrl']).path).split('/')[2]
                    data_dict['extParam'] = (urlparse(data_dict['productUrl']).query).split('=')[1]
                else:
                    data_dict['shopDomain'] = None
                    data_dict['productKey'] = None
                    data_dict['extParam'] = None     
                data_list.append(data_dict)
            print(f'pages {pages_count} done')
            pages_count+=1
    print('finnish')
    return pd.DataFrame.from_records(data_list)

# %%
def get_tokopedia_basic_info(df:pd.DataFrame)->dict:
    date_now = datetime.now().date()
    url = 'https://gql.tokopedia.com/graphql/PDPGetLayoutQuery'
    header = {'Accept':'*/*',
              'Content-Type':'application/json',
              'Dnt':'1',
              'Referer': df['productUrl'],
              'Sec-Ch-Ua':'"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
              'Sec-Ch-Ua-Mobile':'?0',
              'Sec-Ch-Ua-Platform':'Windows',
              'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
              'X-Device':'desktop',
              'X-Source':'tokopedia-lite',
              'X-Tkpd-Akamai':'pdpGetLayout',
              'X-Tkpd-Lite-Service':'zeus',
              'X-Version':'fc1a9ee'
             }
    payload = {"operationName": "PDPGetLayoutQuery",
               "variables": {"shopDomain": df['shopDomain'],
                             "productKey": df['productKey'],
                             "layoutID": "",
                             "apiVersion": 1,
                             "tokonow": {"shopID":  df['shopId'],
                                         "whID": "0",
                                         "serviceType": "ooc"
                                        },
                             "deviceID": "",
                             "userLocation": {"cityID": "",
                                              "addressID": "",
                                              "districtID": "",
                                              "postalCode": "",
                                              "latlon": ""
                                             },
                             "extParam": df['extParam']
                            },
               "query": "fragment ProductVariant on pdpDataProductVariant {\n  errorCode\n  parentID\n  defaultChild\n  sizeChart\n  totalStockFmt\n  variants {\n    productVariantID\n    variantID\n    name\n    identifier\n    option {\n      picture {\n        urlOriginal: url\n        urlThumbnail: url100\n        __typename\n      }\n      productVariantOptionID\n      variantUnitValueID\n      value\n      hex\n      stock\n      __typename\n    }\n    __typename\n  }\n  children {\n    productID\n    price\n    priceFmt\n    slashPriceFmt\n    discPercentage\n    optionID\n    optionName\n    productName\n    productURL\n    picture {\n      urlOriginal: url\n      urlThumbnail: url100\n      __typename\n    }\n    stock {\n      stock\n      isBuyable\n      stockWordingHTML\n      minimumOrder\n      maximumOrder\n      __typename\n    }\n    isCOD\n    isWishlist\n    campaignInfo {\n      campaignID\n      campaignType\n      campaignTypeName\n      campaignIdentifier\n      background\n      discountPercentage\n      originalPrice\n      discountPrice\n      stock\n      stockSoldPercentage\n      startDate\n      endDate\n      endDateUnix\n      appLinks\n      isAppsOnly\n      isActive\n      hideGimmick\n      isCheckImei\n      minOrder\n      __typename\n    }\n    thematicCampaign {\n      additionalInfo\n      background\n      campaignName\n      icon\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n\nfragment ProductMedia on pdpDataProductMedia {\n  media {\n    type\n    urlOriginal: URLOriginal\n    urlThumbnail: URLThumbnail\n    urlMaxRes: URLMaxRes\n    videoUrl: videoURLAndroid\n    prefix\n    suffix\n    description\n    variantOptionID\n    __typename\n  }\n  videos {\n    source\n    url\n    __typename\n  }\n  __typename\n}\n\nfragment ProductCategoryCarousel on pdpDataCategoryCarousel {\n  linkText\n  titleCarousel\n  applink\n  list {\n    categoryID\n    icon\n    title\n    isApplink\n    applink\n    __typename\n  }\n  __typename\n}\n\nfragment ProductHighlight on pdpDataProductContent {\n  name\n  price {\n    value\n    currency\n    priceFmt\n    slashPriceFmt\n    discPercentage\n    __typename\n  }\n  campaign {\n    campaignID\n    campaignType\n    campaignTypeName\n    campaignIdentifier\n    background\n    percentageAmount\n    originalPrice\n    discountedPrice\n    originalStock\n    stock\n    stockSoldPercentage\n    threshold\n    startDate\n    endDate\n    endDateUnix\n    appLinks\n    isAppsOnly\n    isActive\n    hideGimmick\n    __typename\n  }\n  thematicCampaign {\n    additionalInfo\n    background\n    campaignName\n    icon\n    __typename\n  }\n  stock {\n    useStock\n    value\n    stockWording\n    __typename\n  }\n  variant {\n    isVariant\n    parentID\n    __typename\n  }\n  wholesale {\n    minQty\n    price {\n      value\n      currency\n      __typename\n    }\n    __typename\n  }\n  isCashback {\n    percentage\n    __typename\n  }\n  isTradeIn\n  isOS\n  isPowerMerchant\n  isWishlist\n  isCOD\n  preorder {\n    duration\n    timeUnit\n    isActive\n    preorderInDays\n    __typename\n  }\n  __typename\n}\n\nfragment ProductCustomInfo on pdpDataCustomInfo {\n  icon\n  title\n  isApplink\n  applink\n  separator\n  description\n  __typename\n}\n\nfragment ProductInfo on pdpDataProductInfo {\n  row\n  content {\n    title\n    subtitle\n    applink\n    __typename\n  }\n  __typename\n}\n\nfragment ProductDetail on pdpDataProductDetail {\n  content {\n    title\n    subtitle\n    applink\n    showAtFront\n    isAnnotation\n    __typename\n  }\n  __typename\n}\n\nfragment ProductDataInfo on pdpDataInfo {\n  icon\n  title\n  isApplink\n  applink\n  content {\n    icon\n    text\n    __typename\n  }\n  __typename\n}\n\nfragment ProductSocial on pdpDataSocialProof {\n  row\n  content {\n    icon\n    title\n    subtitle\n    applink\n    type\n    rating\n    __typename\n  }\n  __typename\n}\n\nfragment ProductDetailMediaComponent on pdpDataProductDetailMediaComponent {\n  title\n  description\n  contentMedia {\n    url\n    ratio\n    type\n    __typename\n  }\n  show\n  ctaText\n  __typename\n}\n\nquery PDPGetLayoutQuery($shopDomain: String, $productKey: String, $layoutID: String, $apiVersion: Float, $userLocation: pdpUserLocation, $extParam: String, $tokonow: pdpTokoNow, $deviceID: String) {\n  pdpGetLayout(shopDomain: $shopDomain, productKey: $productKey, layoutID: $layoutID, apiVersion: $apiVersion, userLocation: $userLocation, extParam: $extParam, tokonow: $tokonow, deviceID: $deviceID) {\n    requestID\n    name\n    pdpSession\n    basicInfo {\n      alias\n      createdAt\n      isQA\n      id: productID\n      shopID\n      shopName\n      minOrder\n      maxOrder\n      weight\n      weightUnit\n      condition\n      status\n      url\n      needPrescription\n      catalogID\n      isLeasing\n      isBlacklisted\n      isTokoNow\n      menu {\n        id\n        name\n        url\n        __typename\n      }\n      category {\n        id\n        name\n        title\n        breadcrumbURL\n        isAdult\n        isKyc\n        minAge\n        detail {\n          id\n          name\n          breadcrumbURL\n          isAdult\n          __typename\n        }\n        __typename\n      }\n      txStats {\n        transactionSuccess\n        transactionReject\n        countSold\n        paymentVerified\n        itemSoldFmt\n        __typename\n      }\n      stats {\n        countView\n        countReview\n        countTalk\n        rating\n        __typename\n      }\n      __typename\n    }\n    components {\n      name\n      type\n      position\n      data {\n        ...ProductMedia\n        ...ProductHighlight\n        ...ProductInfo\n        ...ProductDetail\n        ...ProductSocial\n        ...ProductDataInfo\n        ...ProductCustomInfo\n        ...ProductVariant\n        ...ProductCategoryCarousel\n        ...ProductDetailMediaComponent\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
              }
    retries = 0
    while retries < 4:
            try:
                request = req.post(url,headers=header,json=payload).json()
                if request is not None:
                    break
                else:
                    continue
            except (req.exceptions.ConnectionError) as e:
                print(f' error {e}')
                retries += 1
                time.sleep(1)
                print(f'try to sleep 10 second, tries count {retries}')
    data = request['data'].get('pdpGetLayout')
    data_dict = {}

    if data is not None:
        basicInfo = data.get('basicInfo')
        components = data.get('components')
        if basicInfo is not None:
            data_dict['alias'] = basicInfo.get('alias')
            data_dict['createdAt'] = basicInfo.get('createdAt')
            data_dict['dateRecorded'] = date_now
            data_dict['isQA'] = basicInfo.get('isQA')
            data_dict['productId'] = basicInfo.get('id')
            data_dict['shopID'] = basicInfo.get('shopID')
            data_dict['shopName'] = basicInfo.get('shopName')
            data_dict['minOrder'] = basicInfo.get('minOrder')
            data_dict['maxOrder'] = basicInfo.get('maxOrder')
            data_dict['weight'] = basicInfo.get('weight')
            data_dict['weightUnit'] = basicInfo.get('weightUnit')
            data_dict['condition'] = basicInfo.get('condition')
            data_dict['status'] = basicInfo.get('status')
            data_dict['productUrl'] = basicInfo.get('url')
            data_dict['needPrescription'] = basicInfo.get('needPrescription')
            data_dict['catalogID'] = basicInfo.get('catalogID')
            data_dict['isLeasing'] = basicInfo.get('isLeasing')
            data_dict['isBlacklisted'] = basicInfo.get('isBlacklisted')
            data_dict['isTokoNow'] = basicInfo.get('isTokoNow')
            if basicInfo.get('menu') is not None:
                data_dict['etalaseId'] = basicInfo['menu'].get('id')
                data_dict['etalaseName'] = basicInfo['menu'].get('name')
                data_dict['etalaseUrl'] = basicInfo['menu'].get('url')
            else:
                data_dict['etalaseId'] = None
                data_dict['etalaseName'] = None
                data_dict['etalaseUrl'] = None

            if basicInfo.get('category') is not None:
                data_dict['categoryId'] = basicInfo['menu'].get('id')
                data_dict['categoryName'] = basicInfo['menu'].get('name')
                data_dict['categoryTitle'] = basicInfo['menu'].get('title')
                data_dict['categoryUrl'] = basicInfo['menu'].get('breadcrumbURL')
                data_dict['isAdult'] = basicInfo['menu'].get('isAdult')
                data_dict['isKyc'] = basicInfo['menu'].get('isKyc')
                data_dict['minAge'] = basicInfo['menu'].get('minAge')
                if basicInfo['category'].get('detail') is not None:
                    temp_data = basicInfo['category'].get('detail')
                    temp_detail_list = []
                    for item in range(0,len(temp_data),1):
                        temp_detail_dict = {}
                        temp_detail_dict['categoryId'] = temp_data[item].get('id')
                        temp_detail_dict['categoryName'] = temp_data[item].get('name')
                        temp_detail_dict['categoryUrl'] = temp_data[item].get('breadcrumbURL')
                        temp_detail_list.append(temp_detail_dict)
                    data_dict['relatedCategory'] = str(temp_detail_list)
                else:
                    data_dict['relatedCategory'] = None


            else:
                data_dict['categoryId'] = None
                data_dict['categoryName'] = None
                data_dict['categoryTitle'] = None
                data_dict['categoryUrl'] = None
                data_dict['isAdult'] = None
                data_dict['isKyc'] = None
                data_dict['minAge'] = None
                data_dict['relatedCategory'] = None
            if basicInfo.get('txStats') is not None:
                data_dict['transactionSuccess'] = basicInfo['txStats'].get('transactionSuccess')
                data_dict['transactionReject'] = basicInfo['txStats'].get('transactionReject')
                data_dict['countSold'] = basicInfo['txStats'].get('countSold')
                data_dict['paymentVerified'] = basicInfo['txStats'].get('paymentVerified')
            else:
                data_dict['transactionSuccess'] = None
                data_dict['transactionReject'] = None
                data_dict['countSold'] = None
                data_dict['paymentVerified'] = None
            if basicInfo.get('stats') is not None:
                data_dict['countView'] = basicInfo['stats'].get('countView')
                data_dict['countReview'] = basicInfo['stats'].get('countReview')
                data_dict['countTalk'] = basicInfo['stats'].get('countTalk')
                data_dict['rating'] = basicInfo['stats'].get('rating')
            else:
                data_dict['countView'] = None
                data_dict['countReview'] = None
                data_dict['countTalk'] = None
                data_dict['rating'] = None
            if components is not None:
                for item in range(0,len(components),1):
                    if components[item].get('name') == 'new_variant_options':
                        if components[item].get('data') is not None:
                            if components[item]['data'][0].get('variants') is not None:
                                identifier = components[item]['data'][0]['variants'][0].get('identifier')
                                if identifier is not None:
                                    identifier_dict = {}
                                    if components[item]['data'][0]['variants'][0].get('option') is not None:
                                        variants_list = []
                                        for var in range(0,len(components[item]['data'][0]['variants'][0].get('option')),1):
                                            variants_list.append(components[item]['data'][0]['variants'][0]['option'][var].get('value'))
                                        identifier_dict[identifier] = variants_list
                                        
                                        data_dict['productVariants'] = str(identifier_dict)
                                    else:
                                        data_dict['productVariants'] = None    
                                else:
                                    data_dict['productVariants'] = None
                            else:
                                data_dict['productVariants'] = None

                        else:
                            data_dict['productVariants'] = None
                    else:
                        pass
            return data_dict
        else:
            pass
    else:
        return None

# %%
def get_review_data()->pd.DataFrame:
    data_list = []
    pages = 1
    while True:

        url = 'https://gql.tokopedia.com/graphql/ReviewList'
        header = {'Accept':'*/*',
                  'Content-Type':'application/json',
                  'Dnt':'1',
                  'Referer':'https://www.tokopedia.com/lovebonitoid/review',
                  'Sec-Ch-Ua':'"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
                  'Sec-Ch-Ua-Mobile':'?0',
                  'Sec-Ch-Ua-Platform':'"Windows"',
                  'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
                  'X-Source':'tokopedia-lite',
                  'X-Tkpd-Lite-Service':'zeus',
                  'X-Version':'6bad28a'
                 }
        payload = {"operationName": "ReviewList",
                   "variables": {"shopID": "9633142",
                                 "page": pages,
                                 "limit": 100,
                                 "sortBy": "create_time desc",
                                 "filterBy": ""
                                },
                   "query": "query ReviewList($shopID: String!, $limit: Int!, $page: Int!, $filterBy: String, $sortBy: String) {\n  productrevGetShopReviewReadingList(shopID: $shopID, limit: $limit, page: $page, filterBy: $filterBy, sortBy: $sortBy) {\n    list {\n      id: reviewID\n      product {\n        productID\n        productName\n        productImageURL\n        productPageURL\n        productStatus\n        isDeletedProduct\n        productVariant {\n          variantID\n          variantName\n          __typename\n        }\n        __typename\n      }\n      rating\n      reviewTime\n      reviewText\n      reviewerID\n      reviewerName\n      avatar\n      replyText\n      replyTime\n      attachments {\n        attachmentID\n        thumbnailURL\n        fullsizeURL\n        __typename\n      }\n      videoAttachments {\n        attachmentID\n        videoUrl\n        __typename\n      }\n      state {\n        isReportable\n        isAnonymous\n        __typename\n      }\n      likeDislike {\n        totalLike\n        likeStatus\n        __typename\n      }\n      badRatingReasonFmt\n      __typename\n    }\n    hasNext\n    shopName\n    totalReviews\n    __typename\n  }\n}\n"
                  }
        retries = 0
        while retries < 4:
                try:
                    request = req.post(url,headers=header,json=payload).json()
                    if request is not None:
                        break
                    else:
                        continue
                except (req.exceptions.ConnectionError) as e:
                    print(f' error {e}')
                    retries += 1
                    time.sleep(1)
                    print(f'try to sleep 10 second, tries count {retries}')

        temp_cursor = request['data']['productrevGetShopReviewReadingList']['list']
        next_pages = request['data']['productrevGetShopReviewReadingList'].get('hasNext')
        for lenght in range(0,len(temp_cursor),1):   
            dict_review_dict = {}
            dict_review_dict['id'] = temp_cursor[lenght].get('id')
            if temp_cursor[lenght].get('product') is not None:
                dict_review_dict['productName'] = temp_cursor[lenght]['product'].get('productName')
                dict_review_dict['productPageURL'] = temp_cursor[lenght]['product'].get('productPageURL')
                dict_review_dict['productStatus'] = temp_cursor[lenght]['product'].get('productStatus')
                dict_review_dict['isDeletedProduct'] = temp_cursor[lenght]['product'].get('isDeletedProduct')
                dict_review_dict['productPageURL'] = temp_cursor[lenght]['product'].get('productPageURL')
                if temp_cursor[lenght]['product'].get('productVariant') is not None:
                    dict_review_dict['productVariantID'] = temp_cursor[lenght]['product'].get('productPageURL')
                    dict_review_dict['productVariantName'] = temp_cursor[lenght]['product'].get('productPageURL')
                else:
                    dict_review_dict['productVariantID'] = None
                    dict_review_dict['productVariantName'] = None
            else:
                dict_review_dict['productName'] = None
                dict_review_dict['productPageURL'] = None
                dict_review_dict['productStatus'] = None
                dict_review_dict['isDeletedProduct'] = None
                dict_review_dict['productPageURL'] = None
                dict_review_dict['productVariantID'] = None
                dict_review_dict['productVariantName'] = None
            dict_review_dict['rating'] = temp_cursor[lenght].get('rating')
            dict_review_dict['reviewTime'] = temp_cursor[lenght].get('reviewTime')
            dict_review_dict['reviewText'] = temp_cursor[lenght].get('reviewText')
            dict_review_dict['reviewerID'] = temp_cursor[lenght].get('reviewerID')
            dict_review_dict['reviewerName'] = temp_cursor[lenght].get('reviewerName')
            dict_review_dict['avatar'] = temp_cursor[lenght].get('avatar')
            dict_review_dict['replyText'] = temp_cursor[lenght].get('replyText')
            dict_review_dict['replyTime'] = temp_cursor[lenght].get('replyTime')
            if temp_cursor[lenght].get('attachments') is not None:
                list_id = []
                list_thumbnail = []
                list_fullsize = []
                for item in range(0,len(temp_cursor[lenght].get('attachments')),1):
                    list_id.append(temp_cursor[lenght]['attachments'][item].get('attachmentID'))
                    list_fullsize.append(temp_cursor[lenght]['attachments'][item].get('fullsizeURL'))
                    list_thumbnail.append(temp_cursor[lenght]['attachments'][item].get('thumbnailURL'))
                dict_review_dict['attachmentID'] = str(list_id)
                dict_review_dict['thumbnailURL'] = str(list_thumbnail)
                dict_review_dict['fullsizeURL'] = str(list_fullsize)
            else:
                dict_review_dict['attachmentID'] = None
                dict_review_dict['thumbnailURL'] = None
                dict_review_dict['fullsizeURL'] = None
            if temp_cursor[lenght].get('state') is not None:    
                dict_review_dict['isReportable'] = temp_cursor[lenght]['state'].get('isReportable')
                dict_review_dict['isAnonymous'] = temp_cursor[lenght]['state'].get('isAnonymous')
            else:
                dict_review_dict['isReportable'] = None
                dict_review_dict['isAnonymous'] = None
            if temp_cursor[lenght].get('likeDislike') is not None:
                dict_review_dict['totalLike'] = temp_cursor[lenght]['likeDislike'].get('totalLike')
                dict_review_dict['likeStatus'] = temp_cursor[lenght]['likeDislike'].get('likeStatus')
            else:
                dict_review_dict['totalLike'] = None
                dict_review_dict['likeStatus'] = None
            dict_review_dict['badRatingReasonFmt'] = temp_cursor[lenght].get('badRatingReasonFmt')
            data_list.append(dict_review_dict)
        if next_pages == False:
            break
        else:
            pages += 1
    return pd.DataFrame.from_records(data_list)

# %%
file_path = "love bonito.db"
shop_id = "9633142"
active_product_table = 'active_product'
product_basic_info_table = 'productBasicInfo'
review_list_table = 'total review'
date_now = datetime.now().date()
date_now = pd.to_datetime(date_now)
if not os.path.exists(file_path):    
    with sqlite3.connect(file_path) as connection:
        pass
else:
    sql_engine = create_engine(f'sqlite:///{file_path}')
    # Create an Inspector
    inspector = inspect(sql_engine)

    # Check if the "my_table" table exists
    #data_dict['productListingStatus'] = 'True'
    df = get_tokopedia_shop_product(shop_id)
    if inspector.has_table(active_product_table):
        query = f"SELECT * FROM {active_product_table} WHERE shopId = '{shop_id}'"
        df_existing = pd.read_sql_query(query, sql_engine)
        # Update table values where df_existing['productId'] matches df['productId']
        mask = df_existing['productId'].isin(df['productId'])
        
        if len(df_existing.loc[~mask, 'productListingStatus'])>0:
            df_existing.loc[~mask, 'productListingStatus'] = False
        elif len(df_existing.loc[mask])>0:
            df_existing.loc[mask] = df[df['productId'].isin(df_existing['productId'])]
        elif len(df[~df['productId'].isin(df_existing['productId'])])>0:
            df_new_rows = df[~df['productId'].isin(df_existing['productId'])]
            df_existing = pd.concat([df_existing, df_new_rows], ignore_index=True)
        else:
            pass
        # Add new rows where df_existing['productId'] not matches df['productId']
        
        
        # Save the updated DataFrame back to the database
        df_existing.to_sql(active_product_table, con=sql_engine, index=False, if_exists='replace')
        #del df_existing, mask, df_new_rows
        # delete variable df_existing
        if inspector.has_table(product_basic_info_table):
            print(f'table {product_basic_info_table} exist')
            print(f'update data')
            temp_df_sql = pd.DataFrame()
            for index in range(0,len(df),1):
                #product_id = df['productId'].iloc[index]
                query = f"SELECT * FROM {product_basic_info_table} WHERE productId == {df['productId'].iloc[index]}"
                df_existing_basicInfo_table = pd.read_sql_query(query, sql_engine)
                df_existing_basicInfo_table['dateRecorded'] = pd.to_datetime(df_existing_basicInfo_table['dateRecorded'])
                #dict_basic_info_data['productVariants'] = dict_basic_info_data['productVariants'].json()
                #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])
                
                #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])
                if (len(df_existing_basicInfo_table) == 1) and (df_existing_basicInfo_table['dateRecorded'].iloc[0] < date_now):
                    dict_basic_info_data = get_tokopedia_basic_info(df.iloc[index])
                    dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
                    dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
                    dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
                    temp_df_sql = pd.concat([temp_df_sql, dict_basic_info_data], ignore_index=True)
                    print(f'update data product id: {dict_basic_info_data["productId"].iloc[0]}; {index}/{len(df)}')
                    

                        
                elif (len(df_existing_basicInfo_table) == 0):
                    dict_basic_info_data = get_tokopedia_basic_info(df.iloc[index])
                    dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
                    dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
                    dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
                    dict_basic_info_data.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='append')
                    print(f'add new data product id: {dict_basic_info_data["productId"].iloc[0]}; {index}/{len(df)}')
                    
                else:
                    print(f'data up to date, check next data; {index}/{len(df)}')
            query = f"SELECT * FROM {product_basic_info_table}"
            df_existing_basicInfo_table = pd.read_sql_query(query, sql_engine)
            df_existing_basicInfo_table.update(temp_df_sql)
            df_existing_basicInfo_table.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='replace')
            reviewData = get_review_data()
            print('update list review table')
            reviewData.to_sql(review_list_table, con=sql_engine, index=False, if_exists='replace')

        else:
            print(f'table {product_basic_info_table} not exist')
            print(f'grabbing new data')   
            dict_basic_info_data = get_tokopedia_basic_info(df.iloc[0])
            dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
            dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
            #dict_basic_info_data['productVariants'] = dict_basic_info_data['productVariants'].json()

            dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
            #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])

            dict_basic_info_data.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='replace')
            for index in range(1,len(df),1):
                print(f'grabbing data product id: {df["productId"].iloc[index]}')
                dict_basic_info_data = get_tokopedia_basic_info(df.iloc[index])
                dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
                dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
                #dict_basic_info_data['productVariants'] = dict_basic_info_data['productVariants'].json()

                dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
                #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])

                dict_basic_info_data.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='append')
            reviewData = get_review_data()
            print('update list review table')
            reviewData.to_sql(review_list_table, con=sql_engine, index=False, if_exists='replace')

    else:
        df.to_sql(active_product_table, con=sql_engine, index=False)
        print(f'grabbing new data')   
        dict_basic_info_data = get_tokopedia_basic_info(df.iloc[0])
        dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
        dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
        #dict_basic_info_data['productVariants'] = dict_basic_info_data['productVariants'].json()

        dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
        #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])

        dict_basic_info_data.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='replace')
        for index in range(1,len(df),1):
            print(f'grabbing data product id: {df["productId"].iloc[index]}')
            dict_basic_info_data = get_tokopedia_basic_info(df.iloc[index])
            dict_basic_info_data = pd.DataFrame([dict_basic_info_data])
            dict_basic_info_data['dateRecorded'] = pd.to_datetime(dict_basic_info_data['dateRecorded'])
            #dict_basic_info_data['productVariants'] = dict_basic_info_data['productVariants'].json()

            dict_basic_info_data.drop_duplicates(subset='productId', keep='first', inplace=True, ignore_index=False)
            #dict_basic_info_data['productVariants'] = json.dumps(dict_basic_info_data['productVariants'])
            dict_basic_info_data.to_sql(product_basic_info_table, con=sql_engine, index=False, if_exists='append')
        reviewData = get_review_data()
        print('update list review table')
        reviewData.to_sql(review_list_table, con=sql_engine, index=False, if_exists='replace')
# Out:
# pages 1 done
# pages 2 done
# pages 3 done
# pages 4 done
# pages 5 done
# pages 6 done
# pages 7 done
# pages 8 done
# pages 9 done
# pages 10 done
# pages 11 done
# pages 12 done
# pages 13 done
# pages 14 done
# pages 15 done
# pages 16 done
# pages 17 done
# pages 18 done
# pages 19 done
# pages 20 done
# pages 21 done
# pages 22 done
# pages 23 done
# pages 24 done
# pages 25 done
# pages 26 done
# pages 27 done
# pages 28 done
# pages 29 done
# pages 30 done
# pages 31 done
# pages 32 done
# pages 33 done
# pages 34 done
# pages 35 done
# pages 36 done
# pages 37 done
# pages 38 done
# pages 39 done
# pages 40 done
# pages 41 done
# pages 42 done
# pages 43 done
# pages 44 done
# pages 45 done
# pages 46 done
# pages 47 done
# pages 48 done
# pages 49 done
# pages 50 done
# pages 51 done
# pages 52 done
# pages 53 done
# pages 54 done
# pages 55 done
# pages 56 done
# pages 57 done
# pages 58 done
# pages 59 done
# pages 60 done
# pages 61 done
# pages 62 done
# pages 63 done
# pages 64 done
# pages 65 done
# finnish
# C:\Users\snsv\AppData\Local\Temp\ipykernel_2560\1900641669.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False False ...  True  True  True]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_existing.loc[mask] = df[df['productId'].isin(df_existing['productId'])]
# C:\Users\snsv\AppData\Local\Temp\ipykernel_2560\1900641669.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False False ... False False False]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_existing.loc[mask] = df[df['productId'].isin(df_existing['productId'])]
# table productBasicInfo exist
# update data
# update data product id: 12410532789; 0/4349
# update data product id: 12410229280; 1/4349
# update data product id: 12410123967; 2/4349
# update data product id: 12410020129; 3/4349
# update data product id: 12409958831; 4/4349
# update data product id: 12353202955; 5/4349
# update data product id: 12352987727; 6/4349
# update data product id: 12353135034; 7/4349
# update data product id: 12352781616; 8/4349
# update data product id: 12353123763; 9/4349
# update data product id: 12352620734; 10/4349
# update data product id: 12352513792; 11/4349
# update data product id: 12379520556; 12/4349
# update data product id: 12352379941; 13/4349
# update data product id: 12352354860; 14/4349
# update data product id: 12352273181; 15/4349
# update data product id: 12379342406; 16/4349
# update data product id: 12352134820; 17/4349
# update data product id: 12351984563; 18/4349
# update data product id: 12351802813; 19/4349
# update data product id: 12350838083; 20/4349
# update data product id: 12346348184; 21/4349
# update data product id: 12346289863; 22/4349
# update data product id: 12346247692; 23/4349
# update data product id: 12346070762; 24/4349
# update data product id: 12345941230; 25/4349
# update data product id: 12345804702; 26/4349
# update data product id: 12345641595; 27/4349
# update data product id: 12345414392; 28/4349
# update data product id: 12337185660; 29/4349
# update data product id: 12327993463; 30/4349
# update data product id: 12327871688; 31/4349
# update data product id: 12327667749; 32/4349
# update data product id: 12327230880; 33/4349
# update data product id: 12326521823; 34/4349
# update data product id: 12326356075; 35/4349
# update data product id: 12325080871; 36/4349
# update data product id: 12324538406; 37/4349
# update data product id: 12302949239; 38/4349
# update data product id: 12301799474; 39/4349
# update data product id: 12301525761; 40/4349
# update data product id: 12301412098; 41/4349
# update data product id: 12300324181; 42/4349
# update data product id: 12299567987; 43/4349
# update data product id: 12299013179; 44/4349
# update data product id: 12298386010; 45/4349
# update data product id: 12299051997; 46/4349
# update data product id: 12291609653; 47/4349
# update data product id: 12290445836; 48/4349
# update data product id: 12288181767; 49/4349
# update data product id: 12286945787; 50/4349
# update data product id: 12286734443; 51/4349
# update data product id: 12282846973; 52/4349
# update data product id: 12282599930; 53/4349
# update data product id: 12282417960; 54/4349
# update data product id: 12281002321; 55/4349
# update data product id: 12249274708; 56/4349
# update data product id: 12248935959; 57/4349
# update data product id: 12248546419; 58/4349
# update data product id: 12248280734; 59/4349
# update data product id: 12279018662; 60/4349
# update data product id: 12243307808; 61/4349
# update data product id: 12243142873; 62/4349
# update data product id: 12242758497; 63/4349
# update data product id: 12242321168; 64/4349
# update data product id: 12242178116; 65/4349
# update data product id: 12242014492; 66/4349
# update data product id: 12241839924; 67/4349
# update data product id: 12241235716; 68/4349
# update data product id: 12240598675; 69/4349
# update data product id: 12240196268; 70/4349
# update data product id: 12235679497; 71/4349
# update data product id: 12234414738; 72/4349
# update data product id: 12223738298; 73/4349
# update data product id: 12223698931; 74/4349
# update data product id: 12223544673; 75/4349
# update data product id: 12218260685; 76/4349
# update data product id: 12218196591; 77/4349
# update data product id: 12218108791; 78/4349
# update data product id: 12218040879; 79/4349
# update data product id: 12217611721; 80/4349
# update data product id: 12217419898; 81/4349
# update data product id: 12217220906; 82/4349
# update data product id: 12215774984; 83/4349
# update data product id: 12215445476; 84/4349
# update data product id: 12215080082; 85/4349
# update data product id: 12197867073; 86/4349
# update data product id: 12197792542; 87/4349
# update data product id: 12188965333; 88/4349
# update data product id: 12188632121; 89/4349
# update data product id: 12188142924; 90/4349
# update data product id: 12186560366; 91/4349
# update data product id: 12186260564; 92/4349
# update data product id: 12185983115; 93/4349
# update data product id: 12178491409; 94/4349
# update data product id: 12177798267; 95/4349
# update data product id: 12157868148; 96/4349
# update data product id: 12157740211; 97/4349
# update data product id: 12130172418; 98/4349
# update data product id: 12128798632; 99/4349
# update data product id: 12127220884; 100/4349
# update data product id: 12119903654; 101/4349
# update data product id: 12116194804; 102/4349
# update data product id: 12115808199; 103/4349
# update data product id: 12115344976; 104/4349
# update data product id: 12114635476; 105/4349
# update data product id: 12114100069; 106/4349
# update data product id: 12058523805; 107/4349
# update data product id: 12056090875; 108/4349
# update data product id: 12053637859; 109/4349
# update data product id: 12029090950; 110/4349
# update data product id: 12028875944; 111/4349
# update data product id: 12028320160; 112/4349
# update data product id: 12028254446; 113/4349
# update data product id: 12016091360; 114/4349
# update data product id: 12015902577; 115/4349
# update data product id: 12015720539; 116/4349
# update data product id: 12015496536; 117/4349
# update data product id: 12011939060; 118/4349
# update data product id: 12011560844; 119/4349
# update data product id: 11996035979; 120/4349
# update data product id: 11994566795; 121/4349
# update data product id: 11992580824; 122/4349
# update data product id: 11985518124; 123/4349
# update data product id: 11954509559; 124/4349
# update data product id: 11953316684; 125/4349
# update data product id: 11943413783; 126/4349
# update data product id: 11943199765; 127/4349
# update data product id: 11942825045; 128/4349
# update data product id: 11939003114; 129/4349
# update data product id: 11938676361; 130/4349
# update data product id: 11936107421; 131/4349
# update data product id: 11933027241; 132/4349
# update data product id: 11932883316; 133/4349
# update data product id: 11884018006; 134/4349
# update data product id: 11883559868; 135/4349
# update data product id: 11879624194; 136/4349
# update data product id: 11879293927; 137/4349
# update data product id: 11875497722; 138/4349
# update data product id: 11875033726; 139/4349
# update data product id: 11874863784; 140/4349
# update data product id: 11874725661; 141/4349
# update data product id: 11873057824; 142/4349
# update data product id: 11871801802; 143/4349
# update data product id: 11871640795; 144/4349
# update data product id: 11854212221; 145/4349
# update data product id: 11853699577; 146/4349
# update data product id: 11851517847; 147/4349
# update data product id: 11851328569; 148/4349
# update data product id: 11827946862; 149/4349
# update data product id: 11827246468; 150/4349
# update data product id: 11812101717; 151/4349
# update data product id: 11810825616; 152/4349
# update data product id: 11809565226; 153/4349
# update data product id: 11807745215; 154/4349
# update data product id: 11806694289; 155/4349
# update data product id: 11801747548; 156/4349
# update data product id: 11800456852; 157/4349
# update data product id: 11800257304; 158/4349
# update data product id: 11799309535; 159/4349
# update data product id: 11798503915; 160/4349
# update data product id: 11797758043; 161/4349
# update data product id: 11796170014; 162/4349
# update data product id: 11862942927; 163/4349
# update data product id: 11786678296; 164/4349
# update data product id: 11786263893; 165/4349
# update data product id: 11785482952; 166/4349
# update data product id: 11785257205; 167/4349
# update data product id: 11781844126; 168/4349
# update data product id: 11781907346; 169/4349
# update data product id: 11781749699; 170/4349
# update data product id: 11781701982; 171/4349
# update data product id: 11781667892; 172/4349
# update data product id: 11781579201; 173/4349
# update data product id: 11767058219; 174/4349
# update data product id: 11765822183; 175/4349
# update data product id: 11765587297; 176/4349
# update data product id: 11749401121; 177/4349
# update data product id: 11748990403; 178/4349
# update data product id: 11746391441; 179/4349
# update data product id: 11746203311; 180/4349
# update data product id: 11746101254; 181/4349
# update data product id: 11745963442; 182/4349
# update data product id: 11734223111; 183/4349
# update data product id: 11733059380; 184/4349
# update data product id: 11732714469; 185/4349
# update data product id: 11730650198; 186/4349
# update data product id: 11711479381; 187/4349
# update data product id: 11710969387; 188/4349
# update data product id: 11681853548; 189/4349
# update data product id: 11681226278; 190/4349
# update data product id: 11677730424; 191/4349
# update data product id: 11677426294; 192/4349
# update data product id: 11675178951; 193/4349
# update data product id: 11675102237; 194/4349
# update data product id: 11649823258; 195/4349
# update data product id: 11649555066; 196/4349
# update data product id: 11642762415; 197/4349
# update data product id: 11638338855; 198/4349
# update data product id: 11637946312; 199/4349
# update data product id: 11637616634; 200/4349
# update data product id: 11592341701; 201/4349
# update data product id: 11592102740; 202/4349
# update data product id: 11589605178; 203/4349
# update data product id: 11583864904; 204/4349
# update data product id: 11581144098; 205/4349
# update data product id: 11578468636; 206/4349
# update data product id: 11572255202; 207/4349
# update data product id: 11571767545; 208/4349
# update data product id: 11570000774; 209/4349
# update data product id: 11562876939; 210/4349
# update data product id: 11562262814; 211/4349
# update data product id: 11558861379; 212/4349
# update data product id: 11558176134; 213/4349
# update data product id: 11548154832; 214/4349
# update data product id: 11544636877; 215/4349
# update data product id: 11543319220; 216/4349
# update data product id: 11539314409; 217/4349
# update data product id: 11530185082; 218/4349
# update data product id: 11530005703; 219/4349
# update data product id: 11529556239; 220/4349
# update data product id: 11526933145; 221/4349
# update data product id: 11526090111; 222/4349
# update data product id: 11523934056; 223/4349
# update data product id: 11519282111; 224/4349
# update data product id: 11499307990; 225/4349
# update data product id: 11498471526; 226/4349
# update data product id: 11497283107; 227/4349
# update data product id: 11486591072; 228/4349
# update data product id: 11486532845; 229/4349
# update data product id: 11486441822; 230/4349
# update data product id: 11481996208; 231/4349
# update data product id: 11481646092; 232/4349
# update data product id: 11474231051; 233/4349
# update data product id: 11474107604; 234/4349
# update data product id: 11473000008; 235/4349
# update data product id: 11472681811; 236/4349
# update data product id: 11472113649; 237/4349
# update data product id: 11464340466; 238/4349
# update data product id: 11464063209; 239/4349
# update data product id: 11444533508; 240/4349
# update data product id: 11443272004; 241/4349
# update data product id: 11442412559; 242/4349
# update data product id: 11440940191; 243/4349
# update data product id: 11393886473; 244/4349
# update data product id: 11393402146; 245/4349
# update data product id: 11392463041; 246/4349
# update data product id: 11392110987; 247/4349
# update data product id: 11391508231; 248/4349
# update data product id: 11385802642; 249/4349
# update data product id: 11385645120; 250/4349
# update data product id: 11385603565; 251/4349
# update data product id: 11385492641; 252/4349
# update data product id: 11385459520; 253/4349
# update data product id: 11313330692; 254/4349
# update data product id: 11309420717; 255/4349
# update data product id: 11308924363; 256/4349
# update data product id: 11298413083; 257/4349
# update data product id: 11298252032; 258/4349
# update data product id: 11297999908; 259/4349
# update data product id: 11289852986; 260/4349
# update data product id: 11287498831; 261/4349
# update data product id: 11287244999; 262/4349
# update data product id: 11265725239; 263/4349
# update data product id: 11265704371; 264/4349
# update data product id: 11265563524; 265/4349
# update data product id: 11253711958; 266/4349
# update data product id: 11252926583; 267/4349
# update data product id: 11252538881; 268/4349
# update data product id: 11138583409; 269/4349
# update data product id: 11138397071; 270/4349
# update data product id: 11128569539; 271/4349
# update data product id: 11128519318; 272/4349
# update data product id: 11128230081; 273/4349
# update data product id: 11123798076; 274/4349
# update data product id: 11122290110; 275/4349
# update data product id: 11110446816; 276/4349
# update data product id: 11100800542; 277/4349
# update data product id: 11083911379; 278/4349
# update data product id: 11083597758; 279/4349
# update data product id: 11083296785; 280/4349
# update data product id: 11073533055; 281/4349
# update data product id: 11073232993; 282/4349
# update data product id: 11072812703; 283/4349
# update data product id: 11034747504; 284/4349
# update data product id: 11034423349; 285/4349
# update data product id: 11034054998; 286/4349
# update data product id: 11033778187; 287/4349
# update data product id: 10919845795; 288/4349
# update data product id: 10919626421; 289/4349
# update data product id: 10917859714; 290/4349
# update data product id: 10902518412; 291/4349
# update data product id: 10902392863; 292/4349
# update data product id: 10902233971; 293/4349
# update data product id: 10902147388; 294/4349
# update data product id: 10836267718; 295/4349
# update data product id: 10835857407; 296/4349
# update data product id: 10829617648; 297/4349
# update data product id: 10829290085; 298/4349
# update data product id: 10828395572; 299/4349
# update data product id: 10827335649; 300/4349
# update data product id: 10784159925; 301/4349
# update data product id: 10783975023; 302/4349
# update data product id: 10782152945; 303/4349
# update data product id: 10781665959; 304/4349
# update data product id: 10781104500; 305/4349
# update data product id: 10766925758; 306/4349
# update data product id: 10655002495; 307/4349
# update data product id: 10654375015; 308/4349
# update data product id: 10654023452; 309/4349
# update data product id: 10653340014; 310/4349
# update data product id: 10652899066; 311/4349
# update data product id: 10649890970; 312/4349
# update data product id: 10649320399; 313/4349
# update data product id: 10624817053; 314/4349
# update data product id: 10624389817; 315/4349
# update data product id: 10623036312; 316/4349
# update data product id: 10622405091; 317/4349
# update data product id: 10592273823; 318/4349
# update data product id: 10592222276; 319/4349
# update data product id: 10592206992; 320/4349
# update data product id: 10592176747; 321/4349
# update data product id: 10573644198; 322/4349
# update data product id: 10573491422; 323/4349
# update data product id: 10573349073; 324/4349
# update data product id: 10573274717; 325/4349
# update data product id: 10551409280; 326/4349
# update data product id: 10551271349; 327/4349
# update data product id: 10544912331; 328/4349
# update data product id: 10544824983; 329/4349
# update data product id: 10544762895; 330/4349
# update data product id: 10504673111; 331/4349
# update data product id: 10504612570; 332/4349
# update data product id: 10504507499; 333/4349
# update data product id: 10494704170; 334/4349
# update data product id: 10494640944; 335/4349
# update data product id: 10494489541; 336/4349
# update data product id: 10494407768; 337/4349
# update data product id: 10476673702; 338/4349
# update data product id: 10476222142; 339/4349
# update data product id: 10431692705; 340/4349
# update data product id: 10431476035; 341/4349
# update data product id: 10360653193; 342/4349
# update data product id: 10360501251; 343/4349
# update data product id: 10356878241; 344/4349
# update data product id: 10356712695; 345/4349
# update data product id: 10356502758; 346/4349
# update data product id: 10356150686; 347/4349
# update data product id: 10356029213; 348/4349
# update data product id: 10355947838; 349/4349
# update data product id: 10355739152; 350/4349
# update data product id: 10355595924; 351/4349
# update data product id: 10355408903; 352/4349
# update data product id: 10355350316; 353/4349
# update data product id: 10355011091; 354/4349
# update data product id: 10354856526; 355/4349
# update data product id: 10354543821; 356/4349
# update data product id: 10354448565; 357/4349
# update data product id: 10354370646; 358/4349
# update data product id: 10275064648; 359/4349
# update data product id: 10275040092; 360/4349
# update data product id: 10275018949; 361/4349
# update data product id: 10274972424; 362/4349
# update data product id: 10274914713; 363/4349
# update data product id: 10274734821; 364/4349
# update data product id: 10274729242; 365/4349
# update data product id: 10274658111; 366/4349
# update data product id: 10274607866; 367/4349
# update data product id: 10274561162; 368/4349
# update data product id: 10041821137; 369/4349
# update data product id: 10041584708; 370/4349
# update data product id: 10041448212; 371/4349
# update data product id: 10041356474; 372/4349
# update data product id: 10041253202; 373/4349
# update data product id: 10041069983; 374/4349
# update data product id: 10040706991; 375/4349
# update data product id: 10040249152; 376/4349
# update data product id: 10040008034; 377/4349
# update data product id: 10039836059; 378/4349
# update data product id: 9943996555; 379/4349
# update data product id: 9943854943; 380/4349
# update data product id: 9943755779; 381/4349
# update data product id: 9943459179; 382/4349
# update data product id: 9943375146; 383/4349
# update data product id: 9943148939; 384/4349
# update data product id: 9943080287; 385/4349
# update data product id: 9942892136; 386/4349
# update data product id: 9942482807; 387/4349
# update data product id: 9942307569; 388/4349
# update data product id: 9849220546; 389/4349
# update data product id: 9695846763; 390/4349
# update data product id: 9695774619; 391/4349
# update data product id: 9695531363; 392/4349
# update data product id: 9695471682; 393/4349
# update data product id: 9695356250; 394/4349
# update data product id: 9695325448; 395/4349
# update data product id: 9695225198; 396/4349
# update data product id: 9695027085; 397/4349
# update data product id: 9694725674; 398/4349
# update data product id: 9694659439; 399/4349
# update data product id: 9694615095; 400/4349
# update data product id: 9694538281; 401/4349
# update data product id: 9694429150; 402/4349
# update data product id: 9694362836; 403/4349
# update data product id: 9694308731; 404/4349
# update data product id: 9694234890; 405/4349
# update data product id: 9521079862; 406/4349
# update data product id: 9521079193; 407/4349
# update data product id: 9521078972; 408/4349
# update data product id: 9521078642; 409/4349
# update data product id: 9521078501; 410/4349
# update data product id: 9521078493; 411/4349
# update data product id: 9521078460; 412/4349
# update data product id: 9521078448; 413/4349
# update data product id: 9521078428; 414/4349
# update data product id: 9521078390; 415/4349
# update data product id: 9521078367; 416/4349
# update data product id: 9428126313; 417/4349
# update data product id: 9428124582; 418/4349
# update data product id: 9428123745; 419/4349
# update data product id: 9428121531; 420/4349
# update data product id: 9428120539; 421/4349
# update data product id: 9428119517; 422/4349
# update data product id: 9359689144; 423/4349
# update data product id: 9356236110; 424/4349
# update data product id: 9356231705; 425/4349
# update data product id: 9356229674; 426/4349
# update data product id: 9356227492; 427/4349
# update data product id: 9356225188; 428/4349
# update data product id: 9356224324; 429/4349
# update data product id: 9356222401; 430/4349
# update data product id: 9356220181; 431/4349
# update data product id: 9356217636; 432/4349
# update data product id: 9356215902; 433/4349
# update data product id: 9356213443; 434/4349
# update data product id: 9355319131; 435/4349
# update data product id: 9351172351; 436/4349
# update data product id: 9303383447; 437/4349
# update data product id: 9303383098; 438/4349
# update data product id: 9303382901; 439/4349
# update data product id: 9239742410; 440/4349
# update data product id: 9226759577; 441/4349
# update data product id: 9226715899; 442/4349
# update data product id: 11686655807; 443/4349
# update data product id: 9226664717; 444/4349
# update data product id: 9226463833; 445/4349
# update data product id: 9226416164; 446/4349
# update data product id: 12217164867; 447/4349
# update data product id: 9226351106; 448/4349
# update data product id: 9216622200; 449/4349
# update data product id: 9216568936; 450/4349
# update data product id: 9214787632; 451/4349
# update data product id: 9214685734; 452/4349
# update data product id: 9157484767; 453/4349
# update data product id: 9157476246; 454/4349
# update data product id: 9157397305; 455/4349
# update data product id: 9155023737; 456/4349
# update data product id: 9989172276; 457/4349
# update data product id: 9154871400; 458/4349
# update data product id: 9154029209; 459/4349
# update data product id: 9153958801; 460/4349
# update data product id: 9153933041; 461/4349
# update data product id: 9099731886; 462/4349
# update data product id: 9099696976; 463/4349
# update data product id: 9099558165; 464/4349
# update data product id: 9099495448; 465/4349
# update data product id: 9099467373; 466/4349
# update data product id: 9099433585; 467/4349
# update data product id: 9099108559; 468/4349
# update data product id: 9098992291; 469/4349
# update data product id: 9098955971; 470/4349
# update data product id: 9098376476; 471/4349
# update data product id: 9098217732; 472/4349
# update data product id: 9098152459; 473/4349
# update data product id: 9097425462; 474/4349
# update data product id: 9097331394; 475/4349
# update data product id: 9097279056; 476/4349
# update data product id: 9097191161; 477/4349
# update data product id: 9027357072; 478/4349
# update data product id: 9021491401; 479/4349
# update data product id: 9021208988; 480/4349
# update data product id: 9788931667; 481/4349
# update data product id: 8830665524; 482/4349
# update data product id: 8826823939; 483/4349
# update data product id: 8821796177; 484/4349
# update data product id: 8821524284; 485/4349
# update data product id: 8821421780; 486/4349
# update data product id: 8820540172; 487/4349
# update data product id: 8820300857; 488/4349
# update data product id: 8819930154; 489/4349
# update data product id: 8819614021; 490/4349
# update data product id: 8819317344; 491/4349
# update data product id: 8818566491; 492/4349
# update data product id: 8816975461; 493/4349
# update data product id: 8816419822; 494/4349
# update data product id: 8804654519; 495/4349
# update data product id: 8804449457; 496/4349
# update data product id: 8804254291; 497/4349
# update data product id: 8804107163; 498/4349
# update data product id: 8803614296; 499/4349
# update data product id: 8803508682; 500/4349
# update data product id: 8799038930; 501/4349
# update data product id: 8798982869; 502/4349
# update data product id: 8798858223; 503/4349

# %%
test_df = get_review_data()
test_df
# Out:
#              id                                        productName  \
# 0     988683257  Love, Bonito - Atasan - Aster Padded Embroider...
# 1     988169922  Love, Bonito - Pvara Regular Flare Pants - Bla...
# 2     988169863  Love, Bonito- Jacinth Elastic Chambray Drawstr...
# 3     986443278  Love, Bonito - Jumpsuit - Reese Relaxed Jogger...
# 4     986424079  Love, Bonito - Jumpsuit Wanita - Josefa Cotton...
# ...         ...                                                ...
# 1763  280162867  Heloise Camisole Top in Chamomile Dream - Navy...
# 1764  278350111  Everlee Midi Camisole Dress in Botanica Bloom ...
# 1765  276556688                        Marjo Pleated Dress - White
# 1766  266912100              Oakley Lace Trim Camisole Top - Black
# 1767  264747424        Donatella Belted Straight Leg Pants - Black
#
#                                          productPageURL  productStatus  \
# 0     https://www.tokopedia.com/lovebonitoid/love-bo...              0
# 1     https://www.tokopedia.com/lovebonitoid/love-bo...              0
# 2     https://www.tokopedia.com/lovebonitoid/love-bo...              0
# 3     https://www.tokopedia.com/lovebonitoid/love-bo...              0
# 4     https://www.tokopedia.com/lovebonitoid/love-bo...              0
# ...                                                 ...            ...
# 1763  https://www.tokopedia.com/lovebonitoid/heloise...              0
# 1764  https://www.tokopedia.com/lovebonitoid/everlee...              0
# 1765  https://www.tokopedia.com/lovebonitoid/marjo-p...              0
# 1766  https://www.tokopedia.com/lovebonitoid/oakley-...              0
# 1767  https://www.tokopedia.com/lovebonitoid/donatel...              0
#
#       isDeletedProduct                                   productVariantID  \
# 0                False  https://www.tokopedia.com/lovebonitoid/love-bo...
# 1                False  https://www.tokopedia.com/lovebonitoid/love-bo...
# 2                False  https://www.tokopedia.com/lovebonitoid/love-bo...
# 3                False  https://www.tokopedia.com/lovebonitoid/love-bo...
# 4                False  https://www.tokopedia.com/lovebonitoid/love-bo...
# ...                ...                                                ...
# 1763             False  https://www.tokopedia.com/lovebonitoid/heloise...
# 1764             False  https://www.tokopedia.com/lovebonitoid/everlee...
# 1765             False  https://www.tokopedia.com/lovebonitoid/marjo-p...
# 1766             False  https://www.tokopedia.com/lovebonitoid/oakley-...
# 1767             False  https://www.tokopedia.com/lovebonitoid/donatel...
#
#                                      productVariantName  rating  \
# 0     https://www.tokopedia.com/lovebonitoid/love-bo...       5
# 1     https://www.tokopedia.com/lovebonitoid/love-bo...       5
# 2     https://www.tokopedia.com/lovebonitoid/love-bo...       5
# 3     https://www.tokopedia.com/lovebonitoid/love-bo...       5
# 4     https://www.tokopedia.com/lovebonitoid/love-bo...       5
# ...                                                 ...     ...
# 1763  https://www.tokopedia.com/lovebonitoid/heloise...       5
# 1764  https://www.tokopedia.com/lovebonitoid/everlee...       5
# 1765  https://www.tokopedia.com/lovebonitoid/marjo-p...       5
# 1766  https://www.tokopedia.com/lovebonitoid/oakley-...       3
# 1767  https://www.tokopedia.com/lovebonitoid/donatel...       5
#
#                    reviewTime  \
# 0                 1 hari lalu
# 1                 2 hari lalu
# 2                 2 hari lalu
# 3                 6 hari lalu
# 4                 6 hari lalu
# ...                       ...
# 1763  Lebih dari 1 tahun lalu
# 1764  Lebih dari 1 tahun lalu
# 1765  Lebih dari 1 tahun lalu
# 1766  Lebih dari 1 tahun lalu
# 1767  Lebih dari 1 tahun lalu
#
#                                              reviewText reviewerID  \
# 0                                                baguus   40221537
# 1                             Thx, cakep sesuai display   16292300
# 2                             Thx, cakep sesuai display   16292300
# 3     Really love their clothes, particullary their ...     649087
# 4     I am a fan of this brand. Not the 1st item pur...     649087
# ...                                                 ...        ...
# 1763                   Bahannya soft, sesuai ekspektasi   17892605
# 1764  Aduuh ini sih bagus banget ya cutting dan baha...          0
# 1765  bagus dress nya, sangat versatile design nya d...   15553697
# 1766                            ukurannya XLnya kayak M          0
# 1767                                    KEREN BANGET !!     910626
#
#      reviewerName                                             avatar  \
# 0           Henny  https://accounts.tokopedia.com/image/v1/u/4022...
# 1           Pekak  https://accounts.tokopedia.com/image/v1/u/1629...
# 2           Pekak  https://accounts.tokopedia.com/image/v1/u/1629...
# 3          Bitter  https://accounts.tokopedia.com/image/v1/u/6490...
# 4          Bitter  https://accounts.tokopedia.com/image/v1/u/6490...
# ...           ...                                                ...
# 1763       Adelia  https://accounts.tokopedia.com/image/v1/u/1789...
# 1764        Y***e  https://images.tokopedia.net/img/cache/100-squ...
# 1765       Albert  https://accounts.tokopedia.com/image/v1/u/1555...
# 1766        Y***a  https://images.tokopedia.net/img/cache/100-squ...
# 1767         Iyem  https://accounts.tokopedia.com/image/v1/u/9106...
#
#                                               replyText  \
# 0     Terima kasih telah berbelanja di Love, Bonito ...
# 1     Terima kasih telah berbelanja di Love, Bonito ...
# 2     Terima kasih telah berbelanja di Love, Bonito ...
# 3     Terima kasih telah berbelanja di Love, Bonito ...
# 4     Terima kasih telah berbelanja di Love, Bonito ...
# ...                                                 ...
# 1763  Terima kasih telah berbelanja di Love, Bonito ...
# 1764  Terima kasih telah berbelanja di Love, Bonito ...
# 1765  Terima kasih telah berbelanja di Love, Bonito ...
# 1766  Mohon maaf atas pengalaman buruk yang telah ka...
# 1767
#
#                     replyTime   attachmentID  \
# 0                 1 hari lalu             []
# 1                 2 hari lalu             []
# 2                 2 hari lalu             []
# 3                 6 hari lalu  ['117248646']
# 4                 6 hari lalu  ['117245908']
# ...                       ...            ...
# 1763  Lebih dari 1 tahun lalu             []
# 1764  Lebih dari 1 tahun lalu   ['25208286']
# 1765  Lebih dari 1 tahun lalu             []
# 1766  Lebih dari 1 tahun lalu             []
# 1767                                      []
#
#                                            thumbnailURL  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     ['https://images.tokopedia.net/img/cache/200-s...
# 4     ['https://images.tokopedia.net/img/cache/200-s...
# ...                                                 ...
# 1763                                                 []
# 1764  ['https://images.tokopedia.net/img/cache/200-s...
# 1765                                                 []
# 1766                                                 []
# 1767                                                 []
#
#                                             fullsizeURL  isReportable  \
# 0                                                    []         False
# 1                                                    []         False
# 2                                                    []         False
# 3     ['https://images.tokopedia.net/img/cache/600/b...         False
# 4     ['https://images.tokopedia.net/img/cache/600/b...         False
# ...                                                 ...           ...
# 1763                                                 []         False
# 1764  ['https://images.tokopedia.net/img/cache/600/b...         False
# 1765                                                 []         False
# 1766                                                 []         False
# 1767                                                 []         False
#
#       isAnonymous  totalLike  likeStatus badRatingReasonFmt
# 0           False          0           0
# 1           False          0           0
# 2           False          0           0
# 3           False          0           0
# 4           False          0           0
# ...           ...        ...         ...                ...
# 1763        False          0           0
# 1764         True          0           0
# 1765        False          0           0
# 1766         True          0           0
# 1767        False          0           0
#
# [1768 rows x 23 columns]

# %%
dict_review_dict = {}
dict_review_dict['id'] = temp_cursor.get('id')
if temp_cursor.get('product') is not None:
    dict_review_dict['productName'] = temp_cursor['product'].get('productName')
    dict_review_dict['productPageURL'] = temp_cursor['product'].get('productPageURL')
    dict_review_dict['productStatus'] = temp_cursor['product'].get('productStatus')
    dict_review_dict['isDeletedProduct'] = temp_cursor['product'].get('isDeletedProduct')
    dict_review_dict['productPageURL'] = temp_cursor['product'].get('productPageURL')
    if temp_cursor['product'].get('productVariant') is not None:
        dict_review_dict['productVariantID'] = temp_cursor['product'].get('productPageURL')
        dict_review_dict['productVariantName'] = temp_cursor['product'].get('productPageURL')
    else:
        dict_review_dict['productVariantID'] = None
        dict_review_dict['productVariantName'] = None
else:
    dict_review_dict['productName'] = None
    dict_review_dict['productPageURL'] = None
    dict_review_dict['productStatus'] = None
    dict_review_dict['isDeletedProduct'] = None
    dict_review_dict['productPageURL'] = None
    dict_review_dict['productVariantID'] = None
    dict_review_dict['productVariantName'] = None
dict_review_dict['rating'] = temp_cursor.get('rating')
dict_review_dict['reviewTime'] = temp_cursor.get('reviewTime')
dict_review_dict['reviewText'] = temp_cursor.get('reviewText')
dict_review_dict['reviewerID'] = temp_cursor.get('reviewerID')
dict_review_dict['reviewerName'] = temp_cursor.get('reviewerName')
dict_review_dict['avatar'] = temp_cursor.get('avatar')
dict_review_dict['replyText'] = temp_cursor.get('replyText')
dict_review_dict['replyTime'] = temp_cursor.get('replyTime')
if temp_cursor.get('attachments') is not None:
    list_id = []
    list_thumbnail = []
    list_fullsize = []
    for item in range(0,len(temp_cursor.get('attachments')),1):
        list_id.append(temp_cursor['attachments'][item].get('attachmentID'))
        list_fullsize.append(temp_cursor['attachments'][item].get('fullsizeURL'))
        list_thumbnail.append(temp_cursor['attachments'][item].get('thumbnailURL'))
    dict_review_dict['attachmentID'] = str(list_id)
    dict_review_dict['thumbnailURL'] = str(list_thumbnail)
    dict_review_dict['fullsizeURL'] = str(list_fullsize)
else:
    dict_review_dict['attachmentID'] = None
    dict_review_dict['thumbnailURL'] = None
    dict_review_dict['fullsizeURL'] = None
if temp_cursor.get('state') is not None:    
    dict_review_dict['isReportable'] = temp_cursor['state'].get('isReportable')
    dict_review_dict['isAnonymous'] = temp_cursor['state'].get('isAnonymous')
else:
    dict_review_dict['isReportable'] = None
    dict_review_dict['isAnonymous'] = None
if temp_cursor.get('likeDislike') is not None:
    dict_review_dict['totalLike'] = temp_cursor['likeDislike'].get('totalLike')
    dict_review_dict['likeStatus'] = temp_cursor['likeDislike'].get('likeStatus')
else:
    dict_review_dict['totalLike'] = None
    dict_review_dict['likeStatus'] = None
dict_review_dict['badRatingReasonFmt'] = temp_cursor.get('badRatingReasonFmt')
dict_review_dict
# Out:
# {'id': '988683257',
#  'productName': 'Love, Bonito - Atasan - Aster Padded Embroidered Bustier Top - Black',
#  'productPageURL': 'https://www.tokopedia.com/lovebonitoid/love-bonito-atasan-aster-padded-embroidered-bustier-top-black',
#  'productStatus': 0,
#  'isDeletedProduct': False,
#  'productVariantID': 'https://www.tokopedia.com/lovebonitoid/love-bonito-atasan-aster-padded-embroidered-bustier-top-black',
#  'productVariantName': 'https://www.tokopedia.com/lovebonitoid/love-bonito-atasan-aster-padded-embroidered-bustier-top-black',
#  'rating': 5,
#  'reviewTime': '1 hari lalu',
#  'reviewText': 'baguus',
#  'reviewerID': '40221537',
#  'reviewerName': 'Henny',
#  'avatar': 'https://accounts.tokopedia.com/image/v1/u/40221537/user_thumbnail/desktop',
#  'replyText': 'Terima kasih telah berbelanja di Love, Bonito Indonesia. Bagikan link toko kami https://www.tokopedia.com/lovebonitoid kepada teman-teman Anda dan favoritkan Toko kami untuk terus update mengenai stok dan produk terbaru',
#  'replyTime': '1 hari lalu',
#  'attachmentID': '[]',
#  'thumbnailURL': '[]',
#  'fullsizeURL': '[]',
#  'isReportable': True,
#  'isAnonymous': False,
#  'totalLike': 0,
#  'likeStatus': 0,
#  'badRatingReasonFmt': ''}

# %%
pages = 1

payload['variables']['page'] = 40
retries = 0
while retries < 4:
        try:
            request = req.post(url,headers=header,json=payload).json()
            if request is not None:
                break
            else:
                continue
        except (req.exceptions.ConnectionError) as e:
            print(f' error {e}')
            retries += 1
            time.sleep(1)
            print(f'try to sleep 10 second, tries count {retries}')
print(request['data']['productrevGetShopReviewReadingList'].get('hasNext'),pages)
pages += 1
# Out:
# False 1

# %%
request
# Out:
# {'errors': [{'message': 'Invalid Argument',
#    'path': ['productrevGetShopReviewReadingList'],
#    'extensions': {'code': 3,
#     'developerMessage': 'rpc error',
#     'moreInfo': 'Invalid Page',
#     'timestamp': '2024-01-14 01:00:16.070502628 +0700 WIB m=+201682.472365749'}}],
#  'data': {'productrevGetShopReviewReadingList': None}}
